# %% [markdown]
# <a href="https://colab.research.google.com/github/ale-simoes12/projeto_spark/blob/main/sql_spark_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# instalar as dependências
# !apt-get update -qq
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop2.7.tgz
# !tar xf spark-3.1.2-bin-hadoop2.7.tgz
# !pip install -q findspark
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop2.7"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master('local[*]') \
    .appName("Iniciando com Spark") \
    .config('spark.ui.port', '4050') \
    .getOrCreate()

# %%
# !wget -q https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
get_ipython().system_raw('ngrok config add-authtoken 2nWH8OH46OomBqdNLateoPAnq7X_7rsxy6fyUGp4S9JNKdN8x')
get_ipython().system_raw('./ngrok http 4050 &')

# %%
# !curl -s http://localhost:4040/api/

# %%
data = [('Zeca', '35'), ('Eva', '29')]
colNames = ['Nome', 'Idade']

# %%
df = spark.createDataFrame(data, colNames)

# %%
df.show()
# Out:
# +----+-----+
# |Nome|Idade|
# +----+-----+
# |Zeca|   35|
# | Eva|   29|
# +----+-----+

# %%
df.toPandas()
# Out:
#    Nome Idade
# 0  Zeca    35
# 1   Eva    29

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# %%
zipfile.ZipFile('/content/drive/MyDrive/curso-spark/empresas.zip', 'r')
# Out:
# <zipfile.ZipFile filename='/content/drive/MyDrive/curso-spark/empresas.zip' mode='r'>

# %%
zipfile.ZipFile('/content/drive/MyDrive/curso-spark/empresas.zip', 'r').extractall('/content/drive/MyDrive/curso-spark/')

# %%
path = '/content/drive/MyDrive/curso-spark/empresas'

# %%
empresas = spark.read.csv(path)

# %%
empresas = spark.read.csv(path, sep=';', inferSchema=True)

# %%
empresas.count()
# Out:
# 4585679

# %%
zipfile.ZipFile('/content/drive/MyDrive/curso-spark/socios.zip', 'r').extractall('/content/drive/MyDrive/curso-spark/')

# %%
zipfile.ZipFile('/content/drive/MyDrive/curso-spark/estabelecimentos.zip', 'r').extractall('/content/drive/MyDrive/curso-spark/')

# %%
pathesta = '/content/drive/MyDrive/curso-spark/estabelecimentos'
pathsocio = '/content/drive/MyDrive/curso-spark/socios'

# %%
estaa = spark.read.csv(pathesta, sep=';', inferSchema=True)

# %%
socio = spark.read.csv(pathsocio, sep=';', inferSchema=True)

# %%
socio.count()
# Out:
# 2046430

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresasColNames = ['cnpj_basico', 'razao_social_nome_empresarial', 'natureza_juridica', 'qualificacao_do_responsavel', 'capital_social_da_empresa', 'porte_da_empresa', 'ente_federativo_responsavel']

# %%
for item in enumerate(empresasColNames):
  print(item)
# Out:
# (0, 'cnpj_basico')
# (1, 'razao_social_nome_empresarial')
# (2, 'natureza_juridica')
# (3, 'qualificacao_do_responsavel')
# (4, 'capital_social_da_empresa')
# (5, 'porte_da_empresa')
# (6, 'ente_federativo_responsavel')

# %%
for index,colName in enumerate(empresasColNames):
        empresas = empresas.withColumnRenamed(f"_c{index}", colName)

empresas.columns
# Out:
# ['cnpj_basico',
#  'razao_social_nome_empresarial',
#  'natureza_juridica',
#  'qualificacao_do_responsavel',
#  'capital_social_da_empresa',
#  'porte_da_empresa',
#  'ente_federativo_responsavel']

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
estabsColNames = ['cnpj_basico', 'cnpj_ordem', 'cnpj_dv', 'identificador_matriz_filial', 'nome_fantasia', 'situacao_cadastral', 'data_situacao_cadastral', 'motivo_situacao_cadastral', 'nome_da_cidade_no_exterior', 'pais', 'data_de_inicio_atividade', 'cnae_fiscal_principal', 'cnae_fiscal_secundaria', 'tipo_de_logradouro', 'logradouro', 'numero', 'complemento', 'bairro', 'cep', 'uf', 'municipio', 'ddd_1', 'telefone_1', 'ddd_2', 'telefone_2', 'ddd_do_fax', 'fax', 'correio_eletronico', 'situacao_especial', 'data_da_situacao_especial']

sociosColNames = ['cnpj_basico', 'identificador_de_socio', 'nome_do_socio_ou_razao_social', 'cnpj_ou_cpf_do_socio', 'qualificacao_do_socio', 'data_de_entrada_sociedade', 'pais', 'representante_legal', 'nome_do_representante', 'qualificacao_do_representante_legal', 'faixa_etaria']

# %%
print(estabsColNames)
for item in enumerate(estabsColNames):
  print(item)
print(estabsColNames)
# Out:
# ['cnpj_basico', 'cnpj_ordem', 'cnpj_dv', 'identificador_matriz_filial', 'nome_fantasia', 'situacao_cadastral', 'data_situacao_cadastral', 'motivo_situacao_cadastral', 'nome_da_cidade_no_exterior', 'pais', 'data_de_inicio_atividade', 'cnae_fiscal_principal', 'cnae_fiscal_secundaria', 'tipo_de_logradouro', 'logradouro', 'numero', 'complemento', 'bairro', 'cep', 'uf', 'municipio', 'ddd_1', 'telefone_1', 'ddd_2', 'telefone_2', 'ddd_do_fax', 'fax', 'correio_eletronico', 'situacao_especial', 'data_da_situacao_especial']
# (0, 'cnpj_basico')
# (1, 'cnpj_ordem')
# (2, 'cnpj_dv')
# (3, 'identificador_matriz_filial')
# (4, 'nome_fantasia')
# (5, 'situacao_cadastral')
# (6, 'data_situacao_cadastral')
# (7, 'motivo_situacao_cadastral')
# (8, 'nome_da_cidade_no_exterior')
# (9, 'pais')
# (10, 'data_de_inicio_atividade')
# (11, 'cnae_fiscal_principal')
# (12, 'cnae_fiscal_secundaria')
# (13, 'tipo_de_logradouro')
# (14, 'logradouro')
# (15, 'numero')
# (16, 'complemento')
# (17, 'bairro')
# ...

# %%
for index,colName in enumerate(estabsColNames):
        print(index)
        print(colName)
        estaa = estaa.withColumnRenamed(f"_c{index}", colName)
# Out:
# 0
# cnpj_basico
# 1
# cnpj_ordem
# 2
# cnpj_dv
# 3
# identificador_matriz_filial
# 4
# nome_fantasia
# 5
# situacao_cadastral
# 6
# data_situacao_cadastral
# 7
# motivo_situacao_cadastral
# 8
# nome_da_cidade_no_exterior
# 9
# pais
# 10
# data_de_inicio_atividade
# 11
# cnae_fiscal_principal
# 12
# cnae_fiscal_secundaria
# 13
# tipo_de_logradouro
# 14
# logradouro
# 15
# numero
# 16
# complemento
# 17
# bairro
# 18
# cep
# 19
# uf
# 20
# municipio
# 21
# ddd_1
# 22
# telefone_1
# 23
# ddd_2
# 24
# telefone_2
# 25
# ddd_do_fax
# 26
# fax
# 27
# correio_eletronico
# 28
# situacao_especial
# 29
# data_da_situacao_especial

# %%
estaa.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral  data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8                 20011029
# 1               None                   8                 20081231
# 2               None                   8                 19971231
# 3               None                   8                 20081231
# 4  EMBROIDERY & GIFT                   8                 19980429
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       7107
# ...

# %%
for index,colName in enumerate(sociosColNames):
        socio = socio.withColumnRenamed(f"_c{index}", colName)

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
socio.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %%
estaa.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral  data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8                 20011029
# 1               None                   8                 20081231
# 2               None                   8                 19971231
# 3               None                   8                 20081231
# 4  EMBROIDERY & GIFT                   8                 19980429
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       7107
# ...

# %%
from pyspark.sql.types import DoubleType, StringType

# %%
from pyspark.sql.types import DoubleType, StringType
from pyspark.sql import functions as f

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas = empresas.withColumn('capital_social_da_empresa', f.regexp_replace('capital_social_da_empresa', ',', '.'))

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0.00
# 1               2062                           49                      0.00
# 2               3034                           32                      0.00
# 3               2135                           50                      0.00
# 4               2062                           49                   4000.00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
empresas = empresas.withColumn('capital_social_da_empresa', empresas['capital_social_da_empresa'].cast(DoubleType()))

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
df = spark.createDataFrame([(20200924,), (20201022,), (20210215,)], ['data'])
df.toPandas()
# Out:
#        data
# 0  20200924
# 1  20201022
# 2  20210215

# %%
df = df.withColumn("data", f.to_date(df.data.cast(StringType()), 'yyyyMMdd'))
df.printSchema()
# Out:
# root
#  |-- data: date (nullable = true)

# %%
estaa.show(5)
# Out:
# +-----------+----------+-------+---------------------------+-----------------+------------------+-----------------------+-------------------------+--------------------------+----+------------------------+---------------------+----------------------+------------------+--------------------+------+-----------+------------------+-------+---+---------+-----+----------+-----+----------+----------+----+------------------+-----------------+-------------------------+
# |cnpj_basico|cnpj_ordem|cnpj_dv|identificador_matriz_filial|    nome_fantasia|situacao_cadastral|data_situacao_cadastral|motivo_situacao_cadastral|nome_da_cidade_no_exterior|pais|data_de_inicio_atividade|cnae_fiscal_principal|cnae_fiscal_secundaria|tipo_de_logradouro|          logradouro|numero|complemento|            bairro|    cep| uf|municipio|ddd_1|telefone_1|ddd_2|telefone_2|ddd_do_fax| fax|correio_eletronico|situacao_especial|data_da_situacao_especial|
# ...

# %%
estaa = estaa\
            .withColumn(
            "data_situacao_cadastral",
            f.to_date(estaa.data_situacao_cadastral.cast(StringType()), 'yyyyMMdd')
            )\
            .withColumn(
            "data_de_inicio_atividade",
            f.to_date(estaa.data_de_inicio_atividade.cast(StringType()), 'yyyyMMdd')
            )\
            .withColumn(
            "data_da_situacao_especial",
            f.to_date(estaa.data_da_situacao_especial.cast(StringType()), 'yyyyMMdd')
            )

# %%
df = spark.createDataFrame([(1, ), (2, ), (3, ), (None, )], ['data'])
df.toPandas()
# Out:
#    data
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN

# %%
df = spark.createDataFrame([(1.,), (2.,), (3.,), (float('nan'), )], ['data'])
df.toPandas()
# Out:
#    data
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN

# %%
df = spark.createDataFrame([(1.,), (2.,), (3.,), (float('nan'), )], ['data'])
df.show()
# Out:
# +----+
# |data|
# +----+
# | 1.0|
# | 2.0|
# | 3.0|
# | NaN|
# +----+

# %%
df = spark.createDataFrame([('1',), ('2',), ('3',), (None,)], ['data'])
df.toPandas()
# Out:
#    data
# 0     1
# 1     2
# 2     3
# 3  None

# %%
df.show()
# Out:
# +----+
# |data|
# +----+
# |   1|
# |   2|
# |   3|
# |null|
# +----+

# %%
socio.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %%
socio.limit(5).show()
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |        411|                     2|         LILIANA PATRICIA ...|         ***678188**|                   22|                 19940725|null|        ***000000**|                 null|                                  0|           7|
# ...

# %%
socio.select([f.count(f.when(f.isnull(c), 1)).alias(c) for c in socio.columns]).show()
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|   pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |          0|                     0|                          208|                1234|                    0|                        0|2038255|                  0|              1995432|                                  0|           0|
# ...

# %%
socio.na.fill(0).limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %%
socio.na.fill("0").limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %%
socio.limit(5).show()
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |        411|                     2|         LILIANA PATRICIA ...|         ***678188**|                   22|                 19940725|null|        ***000000**|                 null|                                  0|           7|
# ...

# %%
socio.limit(5)
# Out:
# DataFrame[cnpj_basico: int, identificador_de_socio: int, nome_do_socio_ou_razao_social: string, cnpj_ou_cpf_do_socio: string, qualificacao_do_socio: int, data_de_entrada_sociedade: int, pais: int, representante_legal: string, nome_do_representante: string, qualificacao_do_representante_legal: int, faixa_etaria: int]

# %%
socio = socio\
            .withColumn(
            "data_de_entrada_sociedade",
            f.to_date(socio.data_de_entrada_sociedade.cast(StringType()), 'yyyyMMdd')
            )

# %%
socio\
            .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
            .show(5, False)
# Out:
# +-------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|ano_de_entrada|
# +-------------------------------+------------+--------------+
# |LILIANA PATRICIA GUASTAVINO    |7           |1994          |
# |CRISTINA HUNDERTMARK           |7           |1994          |
# |CELSO EDUARDO DE CASTRO STEPHAN|8           |1994          |
# |EDUARDO BERRINGER STEPHAN      |5           |1994          |
# |HANNE MAHFOUD FADEL            |8           |1994          |
# +-------------------------------+------------+--------------+
# only showing top 5 rows

# %%
socio\
            .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
            .orderBy('ano_de_entrada', ascending=False)\
            .show(5, False)
# Out:
# +-----------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social|faixa_etaria|ano_de_entrada|
# +-----------------------------+------------+--------------+
# |JOSE HUMBERTO PAIVA          |6           |2021          |
# |BENILDES BARBOSA RODRIGUES   |8           |2021          |
# |MARCELO MOCELIN              |5           |2021          |
# |ROBERTA BENELLI              |4           |2021          |
# |EDUARDO DE ANDRADE PEIXOTO   |5           |2021          |
# +-----------------------------+------------+--------------+
# only showing top 5 rows

# %%
socio\
            .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
            .orderBy(['ano_de_entrada', 'faixa_etaria'], ascending=[False, False])\
            .show(5, False)
# Out:
# +-----------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social|faixa_etaria|ano_de_entrada|
# +-----------------------------+------------+--------------+
# |EDGAR FRANCISCO DA SILVA     |9           |2021          |
# |WILLIAM WHITING BEACH VEALE  |9           |2021          |
# |ANTONIO TAVARES DE ANDRADE   |9           |2021          |
# |AURA MARIA DE ANDRADE        |9           |2021          |
# |ANTONIA DE SOUSA VIEIRA      |9           |2021          |
# +-----------------------------+------------+--------------+
# only showing top 5 rows

# %%
empresas\
            .where("capital_social_da_empresa==50")\
            .show(5, False)
# Out:
# +-----------+------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial       |natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |17350147   |ERIK MARCELO DOS SANTOS 42107848858 |2135             |50                         |50.0                     |1               |null                       |
# |17833214   |ALEXANDRE MACHADO LIMA 73750123772  |2135             |50                         |50.0                     |1               |null                       |
# ...

# %%
socio\
        .select("nome_do_socio_ou_razao_social")\
        .show(5)
# Out:
# +-----------------------------+
# |nome_do_socio_ou_razao_social|
# +-----------------------------+
# |         LILIANA PATRICIA ...|
# |         CRISTINA HUNDERTMARK|
# |         CELSO EDUARDO DE ...|
# |         EDUARDO BERRINGER...|
# |          HANNE MAHFOUD FADEL|
# +-----------------------------+
# only showing top 5 rows

# %%
socio\
        .select("nome_do_socio_ou_razao_social")\
        .filter(socio.nome_do_socio_ou_razao_social.startswith("RODRIGO"))\
        .filter(socio.nome_do_socio_ou_razao_social.endswith("DIAS"))\
        .limit(10)\
        .toPandas()
# Out:
#   nome_do_socio_ou_razao_social
# 0          RODRIGO BENASSI DIAS
# 1        RODRIGO RUDIBERTO DIAS
# 2        RODRIGO AURELIANO DIAS
# 3     RODRIGO SIMOES LEMOS DIAS
# 4           RODRIGO GEORGE DIAS
# 5  RODRIGO AUGUSTO FELICIO DIAS
# 6        RODRIGO FERNANDES DIAS
# 7          RODRIGO GARRIDO DIAS
# 8         RODRIGO OLIVEIRA DIAS
# 9        RODRIGO GONCALVES DIAS

# %%
df = spark.createDataFrame([('RESTAURANTE DO RUI',), ('Juca restaurantes ltda',), ('Joca Restaurante',)], ['data'])
df.toPandas()
# Out:
#                      data
# 0      RESTAURANTE DO RUI
# 1  Juca restaurantes ltda
# 2        Joca Restaurante

# %%
df\
    .where(f.upper(df.data).like('%RESTAURANTE%'))\
    .show(truncate=False)
# Out:
# +----------------------+
# |data                  |
# +----------------------+
# |RESTAURANTE DO RUI    |
# |Juca restaurantes ltda|
# |Joca Restaurante      |
# +----------------------+

# %%
df\
    .where(f.upper(df.data).like('RESTAURANTE%'))\
    .show(truncate=False)
# Out:
# +------------------+
# |data              |
# +------------------+
# |RESTAURANTE DO RUI|
# +------------------+

# %%
df\
    .where(f.upper(df.data).like('%RESTAURANTE'))\
    .show(truncate=False)
# Out:
# +----------------+
# |data            |
# +----------------+
# |Joca Restaurante|
# +----------------+

# %%
empresas\
    .select('razao_social_nome_empresarial', 'natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa')\
    .filter(f.upper(empresas['razao_social_nome_empresarial']).like('%RESTAURANTE'))\
    .show(15, False)
# Out:
# +----------------------------------------------------+-----------------+----------------+-------------------------+
# |razao_social_nome_empresarial                       |natureza_juridica|porte_da_empresa|capital_social_da_empresa|
# +----------------------------------------------------+-----------------+----------------+-------------------------+
# |MARIA ROZA DOS SANTOS- BAR E RESTAURANTE            |2135             |5               |0.0                      |
# |ELIANIA A. CUSTODIO RESTAURANTE                     |2135             |1               |0.0                      |
# |R. A. D. ABRIL RESTAURANTE                          |2135             |1               |0.0                      |
# |R. DA S. ARAUJO - RESTAURANTE                       |2135             |5               |0.0                      |
# |A C M COUTINHO-LANCHONETE E RESTAURANTE             |2135             |1               |0.0                      |
# ...

# %%
socio\
    .select(f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .where('ano_de_entrada >= 2010')\
    .groupBy('ano_de_entrada')\
    .count()\
    .orderBy('ano_de_entrada', ascending=True)\
    .show()
# Out:
# +--------------+------+
# |ano_de_entrada| count|
# +--------------+------+
# |          2010| 79337|
# |          2011| 83906|
# |          2012| 80101|
# |          2013| 83919|
# |          2014| 80590|
# |          2015| 80906|
# |          2016| 81587|
# |          2017| 90221|
# |          2018| 99935|
# |          2019|118248|
# |          2020|125927|
# |          2021| 56316|
# +--------------+------+

# %%
empresas\
    .select('cnpj_basico', 'porte_da_empresa', 'capital_social_da_empresa')\
    .groupBy('porte_da_empresa')\
    .agg(
        f.avg("capital_social_da_empresa").alias("capital_social_medio"),
        f.count("cnpj_basico").alias("frequencia")
    )\
    .orderBy('porte_da_empresa', ascending=True)\
    .show()
# Out:
# +----------------+--------------------+----------+
# |porte_da_empresa|capital_social_medio|frequencia|
# +----------------+--------------------+----------+
# |            null|    8.35421888053467|      5985|
# |               1|  339994.53313506936|   3129043|
# |               3|  2601001.7677092673|    115151|
# |               5|   708660.4208249798|   1335500|
# +----------------+--------------------+----------+

# %%
empresas\
    .select("capital_social_da_empresa")\
    .summary()\
    .show()
# Out:
# +-------+-------------------------+
# |summary|capital_social_da_empresa|
# +-------+-------------------------+
# |  count|                  4585679|
# |   mean|        503694.5478542675|
# | stddev|     2.1118691490537405E8|
# |    min|                      0.0|
# |    25%|                      0.0|
# |    50%|                   1000.0|
# |    75%|                   7000.0|
# |    max|         3.22014670262E11|
# +-------+-------------------------+

# %%
empresas\
    .select("*")\
    .show(50)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
empresas\
    .select("capital_social_da_empresa")\
    .summary()\
    .show()
# Out:
# +-------+-------------------------+
# |summary|capital_social_da_empresa|
# +-------+-------------------------+
# |  count|                  4585679|
# |   mean|        503694.5478542675|
# | stddev|     2.1118691490537405E8|
# |    min|                      0.0|
# |    25%|                      0.0|
# |    50%|                   1000.0|
# |    75%|                   7000.0|
# |    max|         3.22014670262E11|
# +-------+-------------------------+

# %%
produtos = spark.createDataFrame(
    [
        ('1', 'Bebidas', 'Água mineral'),
        ('2', 'Limpeza', 'Sabão em pó'),
        ('3', 'Frios', 'Queijo'),
        ('4', 'Bebidas', 'Refrigerante'),
        ('5', 'Pet', 'Ração para cães')
    ],
    ['id', 'cat', 'prod']
)

impostos = spark.createDataFrame(
    [
        ('Bebidas', 0.15),
        ('Limpeza', 0.05),
        ('Frios', 0.065),
        ('Carnes', 0.08)
    ],
    ['cat', 'tax']
)

# %%
produtos.join(impostos, 'cat', how='inner')\
    .sort('id')\
    .show()
# Out:
# +-------+---+------------+-----+
# |    cat| id|        prod|  tax|
# +-------+---+------------+-----+
# |Bebidas|  1|Água mineral| 0.15|
# |Limpeza|  2| Sabão em pó| 0.05|
# |  Frios|  3|      Queijo|0.065|
# |Bebidas|  4|Refrigerante| 0.15|
# +-------+---+------------+-----+

# %%
produtos.join(impostos, 'cat', how='left')\
    .sort('id')\
    .show()
# Out:
# +-------+---+---------------+-----+
# |    cat| id|           prod|  tax|
# +-------+---+---------------+-----+
# |Bebidas|  1|   Água mineral| 0.15|
# |Limpeza|  2|    Sabão em pó| 0.05|
# |  Frios|  3|         Queijo|0.065|
# |Bebidas|  4|   Refrigerante| 0.15|
# |    Pet|  5|Ração para cães| null|
# +-------+---+---------------+-----+

# %%
produtos.join(impostos, 'cat', how='right')\
    .sort('id')\
    .show()
# Out:
# +-------+----+------------+-----+
# |    cat|  id|        prod|  tax|
# +-------+----+------------+-----+
# | Carnes|null|        null| 0.08|
# |Bebidas|   1|Água mineral| 0.15|
# |Limpeza|   2| Sabão em pó| 0.05|
# |  Frios|   3|      Queijo|0.065|
# |Bebidas|   4|Refrigerante| 0.15|
# +-------+----+------------+-----+

# %%
produtos.join(impostos, 'cat', how='outer')\
    .sort('id')\
    .show()
# Out:
# +-------+----+---------------+-----+
# |    cat|  id|           prod|  tax|
# +-------+----+---------------+-----+
# | Carnes|null|           null| 0.08|
# |Bebidas|   1|   Água mineral| 0.15|
# |Limpeza|   2|    Sabão em pó| 0.05|
# |  Frios|   3|         Queijo|0.065|
# |Bebidas|   4|   Refrigerante| 0.15|
# |    Pet|   5|Ração para cães| null|
# +-------+----+---------------+-----+

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
socio.printSchema()

# %%
estaa.printSchema()

# %%
empresas_join = estaa.join(empresas, 'cnpj_basico', how='inner')
empresas_join.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
empresas.show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
empresas_join.show(5)
# Out:
# +-----------+----------+-------+---------------------------+--------------------+------------------+-----------------------+-------------------------+--------------------------+----+------------------------+---------------------+----------------------+------------------+------------------+------+-------------------+----------------+--------+---+---------+-----+----------+-----+----------+----------+----+--------------------+-----------------+-------------------------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# ...

# %%
freq = empresas_join\
    .select(
        'cnpj_basico',
        f.year('data_de_inicio_atividade').alias('data_de_inicio')
    )\
    .where('data_de_inicio >= 2010')\
    .groupBy('data_de_inicio')\
    .agg(f.count("cnpj_basico").alias("frequencia"))\
    .orderBy('data_de_inicio', ascending=True).show()
# Out:
# +--------------+----------+
# |data_de_inicio|frequencia|
# +--------------+----------+
# |          2010|    154159|
# |          2011|    172677|
# |          2012|    232480|
# |          2013|    198424|
# |          2014|    202276|
# |          2015|    212523|
# |          2016|    265417|
# |          2017|    237292|
# |          2018|    275435|
# |          2019|    325922|
# |          2020|    400654|
# |          2021|    153275|
# +--------------+----------+

# %%
freq.union(
    freq.select(
        f.lit('Total').alias('data_de_inicio'),
        f.sum(freq.frequencia).alias('frequencia')
    )
).show()
# Out:
# +--------------+----------+
# |data_de_inicio|frequencia|
# +--------------+----------+
# |          2010|    154159|
# |          2011|    172677|
# |          2012|    232480|
# |          2013|    198424|
# |          2014|    202276|
# |          2015|    212523|
# |          2016|    265417|
# |          2017|    237292|
# |          2018|    275435|
# |          2019|    325922|
# |          2020|    400654|
# |          2021|    153275|
# |         Total|   2830534|
# +--------------+----------+

# %%
empresas.createOrReplaceTempView("empresasView")

# %%
spark.sql("SELECT * FROM empresasView").show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
spark\
    .sql("""
        SELECT *
            FROM empresasView
            WHERE capital_social_da_empresa = 50
    """)\
    .show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |   17350147|         ERIK MARCELO DOS ...|             2135|                         50|                     50.0|               1|                       null|
# |   17833214|         ALEXANDRE MACHADO...|             2135|                         50|                     50.0|               1|                       null|
# |   20860830|         YASMIN MOURA DA F...|             2135|                         50|                     50.0|               1|                       null|
# ...

# %%
spark\
    .sql("""
        SELECT porte_da_empresa, MEAN(capital_social_da_empresa) AS Media
            FROM empresasView
            GROUP BY porte_da_empresa
    """)\
    .show(5)
# Out:
# +----------------+------------------+
# |porte_da_empresa|             Media|
# +----------------+------------------+
# |            null|  8.35421888053467|
# |               1|339994.53313506936|
# |               3|2601001.7677092673|
# |               5| 708660.4208249798|
# +----------------+------------------+

# %%
empresas_join.createOrReplaceTempView("empresasJoinView")

# %%
freq = spark\
    .sql("""
        SELECT YEAR(data_de_inicio_atividade) AS data_de_inicio, COUNT(cnpj_basico) AS count
            FROM empresasJoinView
            WHERE YEAR(data_de_inicio_atividade) >= 2010
            GROUP BY data_de_inicio
            ORDER BY data_de_inicio
    """)

freq\
    .show()
# Out:
# +--------------+------+
# |data_de_inicio| count|
# +--------------+------+
# |          2010|154159|
# |          2011|172677|
# |          2012|232480|
# |          2013|198424|
# |          2014|202276|
# |          2015|212523|
# |          2016|265417|
# |          2017|237292|
# |          2018|275435|
# |          2019|325922|
# |          2020|400654|
# |          2021|153275|
# +--------------+------+

# %%
freq.createOrReplaceTempView("freqView")

# %%
spark\
    .sql("""
        SELECT *
            FROM freqView
        UNION ALL
        SELECT 'Total' AS data_de_inicio, SUM(count) AS count
            FROM freqView
    """)\
    .show()
# Out:
# +--------------+-------+
# |data_de_inicio|  count|
# +--------------+-------+
# |          2010| 154159|
# |          2011| 172677|
# |          2012| 232480|
# |          2013| 198424|
# |          2014| 202276|
# |          2015| 212523|
# |          2016| 265417|
# |          2017| 237292|
# |          2018| 275435|
# |          2019| 325922|
# |          2020| 400654|
# |          2021| 153275|
# |         Total|2830534|
# +--------------+-------+

# %%
empresas.write.csv(
    path='/content/drive/MyDrive/curso-spark/empresas/csv',
    mode='overwrite',
    sep=';',
    header=True
)

# %%
empresas2 = spark.read.csv(
    '/content/drive/MyDrive/curso-spark/empresas/csv',
    sep=';',
    inferSchema=True,
    header=True
)

# %%
empresas2.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
empresas2.show()
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
empresas.write.parquet(
    path='/content/drive/MyDrive/curso-spark/empresas/parquet',
    mode='overwrite',
)

# %%
empresas_parquet = spark.read.parquet(
    '/content/drive/MyDrive/curso-spark/empresas/parquet'
)

# %%
empresas_parquet.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
empresas_parquet.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
empresas.coalesce(1).write.csv(
    path='/content/drive/MyDrive/curso-spark/empresas/csv-unico',
    mode='overwrite',
    sep=';',
    header=True
)

# %%
empresas.write.parquet(
    path='/content/drive/MyDrive/curso-spark/empresas/parquet-partitionBy',
    mode='overwrite',
        partitionBy='porte_da_empresa'
)

# %%
spark.stop()
